# %% [markdown]
# <center>
# <img src="https://laelgelcpublic.s3.sa-east-1.amazonaws.com/lael_50_years_narrow_white.png.no_years.400px_96dpi.png" width="300" alt="LAEL 50 years logo">
# <h3>APPLIED LINGUISTICS GRADUATE PROGRAMME (LAEL)</h3>
# </center>
# <hr>

# %% [markdown]
# # Corpus Linguistics - Study 2 - Phase 1 - Eduardo

# %% [markdown]
# This phase aims to adding Eduardo's Target Corpus to the Brazilian Portuguese Multi-Dimensional Analysis.

# %% [markdown]
# ## Required Python packages

# %% [markdown]
# - pandas

# %% [markdown]
# ## Import the required libraries

# %%
import pandas as pd
import os
import sys

# %% [markdown]
# ## Define input variables

# %%
input_directory = 'tagcount/sas'
output_directory = 'cl_st2_ph1_eduardo'

# %% [markdown]
# ## Create output directory

# %%
# Check if the output directory already exists. If it does, do nothing. If it doesn't exist, create it.
if os.path.exists(output_directory):
    print('Output directory already exists.')
else:
    try:
        os.makedirs(output_directory)
        print('Output directory successfully created.')
    except OSError as e:
        print('Failed to create the directory:', e)
        sys.exit(1)
# Out:
# Output directory already exists.

# %% [markdown]
# ## Import the data into DataFrames

# %% [markdown]
# ### Normed frequency counts for the linguistic features

# %%
df_normed = pd.read_csv(f"{input_directory}/normed.tsv", sep='\t')

# %%
df_normed
# Out:
#       file    v000182    v000184    v000181    v000175     v000185    v000172  \
# 0  t000001  15.873016  10.582011  26.455026  21.164021   84.656085  15.873016
# 1  t000002   8.219178   0.000000  30.136986  57.534247  115.068493   8.219178
# 2  t000003  12.658228   0.000000  21.097046  54.852321   97.046414   0.000000
# 3  t000004  11.278195  11.278195  37.593985  30.075188   97.744361  11.278195
# 4  t000005   6.711409   0.000000  16.778523  36.912752  124.161074   0.000000
# 5  t000006  14.577259   2.915452  11.661808  26.239067   72.886297   0.000000
#
#       v000186    v000174    v000171  ...   v000126   v000115   v000146  \
# 0  169.312169  15.873016  37.037037  ...  0.000000  0.000000  0.000000
# 1  180.821918   5.479452  43.835616  ...  0.000000  0.000000  0.000000
# 2  189.873418   4.219409  50.632911  ...  4.219409  8.438819  4.219409
# 3  191.729323   3.759398  37.593985  ...  0.000000  0.000000  3.759398
# 4  197.986577  13.422819  67.114094  ...  6.711409  0.000000  0.000000
# 5  139.941691   8.746356  23.323615  ...  0.000000  0.000000  0.000000
#
#     v000114    v000027   v000038   v000103   v000086   v000034   v000078
# 0  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  8.438819  12.658228  4.219409  0.000000  0.000000  0.000000  0.000000
# 3  0.000000   0.000000  0.000000  3.759398  7.518797  0.000000  0.000000
# 4  0.000000  10.067114  0.000000  0.000000  0.000000  3.355705  0.000000
# 5  0.000000   0.000000  0.000000  2.915452  0.000000  0.000000  5.830904
#
# [6 rows x 191 columns]

# %% [markdown]
# ### Variable index

# %%
df_var_index = pd.read_csv('var_index.txt', sep=' ', header=None)

# %%
df_var_index.columns = ['Variable ID', 'Variable Label', 'Variable Descriptor']

# %%
df_var_index
# Out:
#     Variable ID Variable Label                Variable Descriptor
# 0       v000001        adjaffi  adj.adjective_affiliative.adjaffi
# 1       v000002         adjall           adj.adjective_all.adjall
# 2       v000003        adjattr  adj.adjective_attributive.adjattr
# 3       v000004        adjcolr        adj.adjective_color.adjcolr
# 4       v000005        adjeval   adj.adjective_evaluative.adjeval
# ..          ...            ...                                ...
# 185     v000186          vball                 vb.verbs_all.vball
# 186     v000187     clauselgth        vd.clause_length.clauselgth
# 187     v000188            ttr            vd.type-token_ratio.ttr
# 188     v000189        wrcount              vd.word_count.wrcount
# 189     v000190             wl                  vd.word_length.wl
#
# [190 rows x 3 columns]

# %%
df_var_index.dtypes
# Out:
# Variable ID            object
# Variable Label         object
# Variable Descriptor    object
# dtype: object

# %% [markdown]
# ### CBVR dimension variables

# %%
df_var_dim = pd.read_csv('var_dim.tsv', sep='\t', header=None)

# %% [markdown]
# Note: `var_dim.tsv` was created by enriching `var_index.txt` with the `Mean Score` and `Standard Deviation` of the variables that load the dimensions of the previous study.

# %%
df_var_dim.columns = ['Variable ID', 'Variable Label', 'Variable Descriptor', 'Variable MS', 'Variable SD']

# %%
df_var_dim
# Out:
#    Variable ID Variable Label                Variable Descriptor  Variable MS  \
# 0      v000001        adjaffi  adj.adjective_affiliative.adjaffi         1.46
# 1      v000003        adjattr  adj.adjective_attributive.adjattr        37.66
# 2      v000005        adjeval   adj.adjective_evaluative.adjeval         5.57
# 3      v000008        adjpred  adj.adjective_predicative.adjpred         8.82
# 4      v000010        adjrela   adj.adjective_relational.adjrela        10.98
# ..         ...            ...                                ...          ...
# 87     v000181         vbpriv             vb.verb_private.vbpriv        12.41
# 88     v000182         vbpubl              vb.verb_public.vbpubl         9.76
# 89     v000183            vb2           vb.verb_secondperson.vb2         1.36
# 90     v000188            ttr            vd.type-token_ratio.ttr         0.53
# 91     v000190             wl                  vd.word_length.wl         4.78
#
#     Variable SD
# 0          2.51
# 1         18.66
# 2          4.27
# 3          5.27
# 4          6.23
# ..          ...
# 87         8.11
# 88         6.46
# 89         3.91
# 90         0.07
# 91         0.43
#
# [92 rows x 5 columns]

# %%
df_var_dim.dtypes
# Out:
# Variable ID             object
# Variable Label          object
# Variable Descriptor     object
# Variable MS            float64
# Variable SD            float64
# dtype: object

# %% [markdown]
# ## Replace `Variable ID` by `Variable Label`

# %%
# DataFrames
# 'df_var_index' contains 'Variable ID' and 'Variable Label'
# 'df_normed' has columns matching 'Variable ID'

# Create a mapping dictionary: {Variable ID → Variable Label}
var_mapping = dict(zip(df_var_index['Variable ID'], df_var_index['Variable Label']))

# Create 'df_normed_labeled' by renaming 'df_normed' columns using the mapping dictionary
df_normed_labeled = df_normed.rename(columns=var_mapping)

# Display the updated DataFrame
df_normed_labeled
# Out:
#       file     vbpubl      vbsua     vbpriv    vbexist         vb3    vbaspct  \
# 0  t000001  15.873016  10.582011  26.455026  21.164021   84.656085  15.873016
# 1  t000002   8.219178   0.000000  30.136986  57.534247  115.068493   8.219178
# 2  t000003  12.658228   0.000000  21.097046  54.852321   97.046414   0.000000
# 3  t000004  11.278195  11.278195  37.593985  30.075188   97.744361  11.278195
# 4  t000005   6.711409   0.000000  16.778523  36.912752  124.161074   0.000000
# 5  t000006  14.577259   2.915452  11.661808  26.239067   72.886297   0.000000
#
#         vball     vbcomm      vbact  ...  prn3sngsubj  nqueinfcl     vbinf  \
# 0  169.312169  15.873016  37.037037  ...     0.000000   0.000000  0.000000
# 1  180.821918   5.479452  43.835616  ...     0.000000   0.000000  0.000000
# 2  189.873418   4.219409  50.632911  ...     4.219409   8.438819  4.219409
# 3  191.729323   3.759398  37.593985  ...     0.000000   0.000000  3.759398
# 4  197.986577  13.422819  67.114094  ...     6.711409   0.000000  0.000000
# 5  139.941691   8.746356  23.323615  ...     0.000000   0.000000  0.000000
#
#    nnonfcque    advemph     advpl     nplac  mdconseguir  advmanner  clqueeprp
# 0   0.000000   0.000000  0.000000  0.000000     0.000000   0.000000   0.000000
# 1   0.000000   0.000000  0.000000  0.000000     0.000000   0.000000   0.000000
# 2   8.438819  12.658228  4.219409  0.000000     0.000000   0.000000   0.000000
# 3   0.000000   0.000000  0.000000  3.759398     7.518797   0.000000   0.000000
# 4   0.000000  10.067114  0.000000  0.000000     0.000000   3.355705   0.000000
# 5   0.000000   0.000000  0.000000  2.915452     0.000000   0.000000   5.830904
#
# [6 rows x 191 columns]

# %% [markdown]
# #### Export to a file

# %%
df_normed_labeled.to_excel(f"{output_directory}/df_normed_labeled.xlsx")

# %% [markdown]
# ## Dimension 1

# %% [markdown]
# ### Filter and order `df_normed_labeled` according `dim1_variable_list`

# %% [markdown]
# The negative pole starts at `Reduced progressive clause [vbprogphr]`.

# %%
dim1_variable_list = [
    'prn2obl',
    'vb1',
    'vbment',
    'vbfutir',
    'prn2sngsubj',
    'vbpriv',
    'vbact',
    'advnao',
    'prn1sngsubj',
    'advtime',
    'prn1obl',
    'prnqtf',
    'adjeval',
    'prnposs',
    'advints',
    'qsqu',
    'advampl',
    'advemph',
    'vbqueindic',
    'adjpred',
    'vbinf',
    'advmanner',
    'vbcomm',
    'vbgerall',
    'mdprecisar',
    'clqueeadv',
    'vbproginf',
    'advneg',
    'prnnomsubj',
    'vbprogphr',
    'prnqualcujo',
    'clpassless',
    'adjrela',
    'vbpastprt',
    'nominlzsubj',
    'adjtopi',
    'nabst',
    'wl',
    'adjattr',
    'ncomp',
    'artdef',
    'prpall'
]

# %%
# Ensure only columns from 'dim1_variable_list' remain
df_dim1_normed_filtered = df_normed_labeled[df_normed_labeled.columns.intersection(dim1_variable_list + ['file'])]

# Reorder columns based on 'dim1_variable_list', placing 'file' first
df_dim1_normed_ordered = df_dim1_normed_filtered[['file'] + dim1_variable_list]

# Display the updated DataFrame
df_dim1_normed_ordered
# Out:
#       file    prn2obl        vb1     vbment    vbfutir  prn2sngsubj  \
# 0  t000001  10.582011   5.291005  42.328042   0.000000     5.291005
# 1  t000002   5.479452   0.000000  21.917808  10.958904     2.739726
# 2  t000003   8.438819   8.438819  33.755274   0.000000     4.219409
# 3  t000004   7.518797  18.796992  41.353383   0.000000     3.759398
# 4  t000005  10.067114   3.355705  26.845638   0.000000     6.711409
# 5  t000006   2.915452  11.661808  23.323615   0.000000     2.915452
#
#       vbpriv      vbact     advnao  prn1sngsubj  ...    adjrela  vbpastprt  \
# 0  26.455026  37.037037   0.000000            0  ...  15.873016  31.746032
# 1  30.136986  43.835616   8.219178            0  ...   8.219178  19.178082
# 2  21.097046  50.632911   8.438819            0  ...  21.097046  37.974684
# 3  37.593985  37.593985   0.000000            0  ...   7.518797  45.112782
# 4  16.778523  67.114094  10.067114            0  ...  10.067114  30.201342
# 5  11.661808  23.323615   0.000000            0  ...   8.746356  26.239067
#
#    nominlzsubj    adjtopi       nabst         wl     adjattr      ncomp  \
# 0    15.873016  15.873016   89.947090  34.121693   84.656085  31.746032
# 1     8.219178  24.657534  120.547945  18.342466   98.630137  73.972603
# 2     4.219409  12.658228   80.168776  24.654008  135.021097  88.607595
# 3    15.037594  30.075188  101.503759  25.112782   90.225564  45.112782
# 4    10.067114  23.489933  104.026846  21.922819   80.536913  40.268456
# 5    11.661808  11.661808  122.448980  18.833819   93.294461  87.463557
#
#        artdef      prpall
# 0  148.148148  137.566138
# 1   71.232877  131.506849
# 2   88.607595  168.776371
# 3  101.503759  146.616541
# 4   93.959732  134.228188
# 5  142.857143  177.842566
#
# [6 rows x 43 columns]

# %% [markdown]
# ### Standardizing the normed counts

# %%
# Creating a new DataFrame with the 'file' column retained
df_dim1_standardised = df_dim1_normed_ordered[['file']].copy()

# %%
# Mapping Variable MS and SD for standardisation
var_dim_dict = dict(zip(df_var_dim['Variable Label'], zip(df_var_dim['Variable MS'], df_var_dim['Variable SD'])))

# %%
var_dim_dict
# Out:
# {'adjaffi': (1.46, 2.51),
#  'adjattr': (37.66, 18.66),
#  'adjeval': (5.57, 4.27),
#  'adjpred': (8.82, 5.27),
#  'adjrela': (10.98, 6.23),
#  'adjtopi': (6.31, 6.19),
#  'advampl': (7.04, 5.05),
#  'advemph': (5.06, 3.95),
#  'advhedg': (0.88, 1.3),
#  'advints': (6.59, 4.91),
#  'advlikl': (1.51, 1.67),
#  'advmanner': (2.06, 2.64),
#  'advnao': (7.97, 6.73),
#  'advneg': (0.42, 0.84),
#  'advpl': (4.08, 5.01),
#  'advtime': (5.58, 4.49),
#  'advcomp': (9.38, 5.15),
#  'discmrkr': (5.41, 5.97),
#  'artdef': (113.62, 28.08),
#  'artindef': (14.02, 7.84),
#  'cjadv': (2.34, 2.32),
#  'cjcoorcls': (11.37, 6.04),
#  'cjcncl': (1.64, 2.05),
#  'cjou': (3.39, 4.22),
#  'cjcoorphr': (6.3, 5.36),
#  'cjcond': (1.63, 1.98),
#  'cjfinal': (0.01, 0.08),
#  'clpassless': (1.95, 2.38),
#  'clinfadj': (0.58, 1.06),
#  'clinfadjease': (0.23, 0.62),
#  'clinfprp': (9.1, 4.66),
#  'adjque': (8.96, 4.97),
#  'clqueeadv': (0.53, 1.25),
#  'clqueeprp': (1.05, 1.28),
#  'nounque': (5.85, 3.63),
#  'vbqueindic': (3.76, 3.87),
#  'mddever': (1.21, 1.94),
#  'mdhaver': (0.05, 0.23),
#  'mdpoder': (3.07, 2.89),
#  'mdprecisar': (0.34, 0.79),
#  'mdter': (0.66, 1.08),
#  'nominlzsubj': (6.95, 5.16),
#  'nabst': (52.1, 27.21),
#  'ncogn': (6.85, 5.76),
#  'ncomp': (16.08, 10.46),
#  'nconc': (20.95, 12.25),
#  'nplac': (7.97, 6.82),
#  'nqueinfcl': (0.73, 1.02),
#  'prnnomsubj': (0.64, 1.06),
#  'prnposs': (10.66, 8.98),
#  'prndem': (11.51, 6.94),
#  'prn1sngsubj': (3.09, 5.94),
#  'prn1obl': (2.11, 5.29),
#  'prn2sngsubj': (2.32, 4.0),
#  'prn2obl': (5.06, 8.81),
#  'prn3plusubj': (0.56, 1.1),
#  'prn3sngsubj': (2.69, 4.41),
#  'prn3obl': (7.37, 5.37),
#  'prnqtf': (18.84, 9.98),
#  'objprnrare': (0.88, 1.66),
#  'prnqualcujo': (0.6, 1.03),
#  'prnque': (10.21, 5.5),
#  'prpall': (147.23, 33.79),
#  'qsqu': (1.36, 2.49),
#  'qsyn': (3.7, 7.63),
#  'qsttag': (0.98, 4.17),
#  'contrac': (1.33, 4.3),
#  'vbfutpres': (3.92, 6.18),
#  'vbfutir': (2.73, 3.96),
#  'vbfutpret': (1.81, 2.61),
#  'vbgerall': (8.27, 5.45),
#  'vbimp': (3.48, 6.98),
#  'vbimpf': (8.32, 11.82),
#  'vbinf': (2.55, 2.3),
#  'vbpast': (19.56, 17.32),
#  'vbpastprt': (18.63, 10.68),
#  'vbproginf': (0.16, 0.84),
#  'vbprogphr': (3.26, 2.73),
#  'subjdrop': (13.57, 11.07),
#  'vbsubfut': (2.05, 3.0),
#  'vbsubpast': (1.02, 1.67),
#  'vbsubpres': (6.31, 7.53),
#  'vbact': (36.99, 14.52),
#  'vbcomm': (8.13, 6.41),
#  'vbfacil': (3.81, 2.98),
#  'vb1': (16.22, 18.77),
#  'vbment': (16.87, 11.15),
#  'vbpriv': (12.41, 8.11),
#  'vbpubl': (9.76, 6.46),
#  'vb2': (1.36, 3.91),
#  'ttr': (0.53, 0.07),
#  'wl': (4.78, 0.43)}

# %%
# Loop through columns except 'file'
for col in df_dim1_normed_ordered.columns[1:]:
    if col in var_dim_dict:
        mean_value, sd_value = var_dim_dict[col]
        df_dim1_standardised[col] = (df_dim1_normed_ordered[col] - mean_value) / sd_value

# Display the resulting DataFrame
df_dim1_standardised
# Out:
#       file   prn2obl       vb1    vbment   vbfutir  prn2sngsubj    vbpriv  \
# 0  t000001  0.626789 -0.582259  2.283232 -0.689394     0.742751  1.731816
# 1  t000002  0.047611 -0.864145  0.452718  2.078006     0.104932  2.185818
# 2  t000003  0.383521 -0.414554  1.514374 -0.689394     0.474852  1.071152
# 3  t000004  0.279092  0.137293  2.195819 -0.689394     0.359850  3.105300
# 4  t000005  0.568344 -0.685365  0.894676 -0.689394     1.097852  0.538659
# 5  t000006 -0.243422 -0.242845  0.578800 -0.689394     0.148863 -0.092256
#
#       vbact    advnao  prn1sngsubj  ...   adjrela  vbpastprt  nominlzsubj  \
# 0  0.003239 -1.184250    -0.520202  ...  0.785396   1.228093     1.729267
# 1  0.471461  0.037025    -0.520202  ... -0.443150   0.051319     0.245965
# 2  0.939594  0.069661    -0.520202  ...  1.623924   1.811300    -0.529184
# 3  0.041597 -1.184250    -0.520202  ... -0.555570   2.479661     1.567363
# 4  2.074662  0.311607    -0.520202  ... -0.146531   1.083459     0.604092
# 5 -0.941211 -1.184250    -0.520202  ... -0.358530   0.712459     0.913141
#
#     adjtopi     nabst         wl   adjattr     ncomp    artdef    prpall
# 0  1.544914  1.390926  68.236496  2.518547  1.497709  1.229635 -0.285998
# 1  2.964060  2.515544  31.540618  3.267424  5.534666 -1.509513 -0.465320
# 2  1.025562  1.031561  46.218624  5.217636  6.933804 -0.890755  0.637655
# 3  3.839287  1.815647  47.285539  2.817018  2.775601 -0.431490 -0.018155
# 4  2.775433  1.908374  39.867020  2.297798  2.312472 -0.700152 -0.384783
# 5  0.864589  2.585409  32.683301  2.981482  6.824432  1.041209  0.905965
#
# [6 rows x 43 columns]

# %% [markdown]
# ### Computing the dimension scores

# %%
dim1_variable_list_pos = [
    'prn2obl',
    'vb1',
    'vbment',
    'vbfutir',
    'prn2sngsubj',
    'vbpriv',
    'vbact',
    'advnao',
    'prn1sngsubj',
    'advtime',
    'prn1obl',
    'prnqtf',
    'adjeval',
    'prnposs',
    'advints',
    'qsqu',
    'advampl',
    'advemph',
    'vbqueindic',
    'adjpred',
    'vbinf',
    'advmanner',
    'vbcomm',
    'vbgerall',
    'mdprecisar',
    'clqueeadv',
    'vbproginf',
    'advneg',
    'prnnomsubj'
]

# %%
dim1_variable_list_neg = [
    'vbprogphr',
    'prnqualcujo',
    'clpassless',
    'adjrela',
    'vbpastprt',
    'nominlzsubj',
    'adjtopi',
    'nabst',
    'wl',
    'adjattr',
    'ncomp',
    'artdef',
    'prpall'
]

# %%
# Calculate the sum of positive pole variables
df_dim1_standardised['dim_scores'] = df_dim1_standardised[dim1_variable_list_pos].sum(axis=1)

# Subtract the sum of negative pole variables
df_dim1_standardised['dim_scores'] -= df_dim1_standardised[dim1_variable_list_neg].sum(axis=1)

# Display the updated DataFrame
df_dim1_standardised
# Out:
#       file   prn2obl       vb1    vbment   vbfutir  prn2sngsubj    vbpriv  \
# 0  t000001  0.626789 -0.582259  2.283232 -0.689394     0.742751  1.731816
# 1  t000002  0.047611 -0.864145  0.452718  2.078006     0.104932  2.185818
# 2  t000003  0.383521 -0.414554  1.514374 -0.689394     0.474852  1.071152
# 3  t000004  0.279092  0.137293  2.195819 -0.689394     0.359850  3.105300
# 4  t000005  0.568344 -0.685365  0.894676 -0.689394     1.097852  0.538659
# 5  t000006 -0.243422 -0.242845  0.578800 -0.689394     0.148863 -0.092256
#
#       vbact    advnao  prn1sngsubj  ...  vbpastprt  nominlzsubj   adjtopi  \
# 0  0.003239 -1.184250    -0.520202  ...   1.228093     1.729267  1.544914
# 1  0.471461  0.037025    -0.520202  ...   0.051319     0.245965  2.964060
# 2  0.939594  0.069661    -0.520202  ...   1.811300    -0.529184  1.025562
# 3  0.041597 -1.184250    -0.520202  ...   2.479661     1.567363  3.839287
# 4  2.074662  0.311607    -0.520202  ...   1.083459     0.604092  2.775433
# 5 -0.941211 -1.184250    -0.520202  ...   0.712459     0.913141  0.864589
#
#       nabst         wl   adjattr     ncomp    artdef    prpall  dim_scores
# 0  1.390926  68.236496  2.518547  1.497709  1.229635 -0.285998  -99.301663
# 1  2.515544  31.540618  3.267424  5.534666 -1.509513 -0.465320  -42.022774
# 2  1.031561  46.218624  5.217636  6.933804 -0.890755  0.637655  -73.813133
# 3  1.815647  47.285539  2.817018  2.775601 -0.431490 -0.018155  -77.326101
# 4  1.908374  39.867020  2.297798  2.312472 -0.700152 -0.384783  -59.211327
# 5  2.585409  32.683301  2.981482  6.824432  1.041209  0.905965  -69.690676
#
# [6 rows x 44 columns]

# %% [markdown]
# #### Export to a file

# %%
df_dim1_standardised.to_excel(f"{output_directory}/df_dim1_standardised.xlsx")

# %% [markdown]
# ### Computing the mean dimension scores for the new registers

# %%
mean_dim1_scores = df_dim1_standardised['dim_scores'].mean()
mean_dim1_scores
# Out:
# -70.22761216807842

# %% [markdown]
# ## Dimension 2

# %% [markdown]
# ### Filter and order `df_normed_labeled` according `dim2_variable_list`

# %% [markdown]
# This dimension has no negative pole.

# %%
dim2_variable_list = [
    'nounque',
    'prnque',
    'advcomp',
    'ncogn',
    'nqueinfcl',
    'clinfadj',
    'clqueeprp',
    'prndem',
    'clinfprp',
    'adjque',
    'clinfadjease',
    'advhedg',
    'artindef',
    'vbfutpret',
    'cjadv'
]

# %%
# Ensure only columns from 'dim2_variable_list' remain
df_dim2_normed_filtered = df_normed_labeled[df_normed_labeled.columns.intersection(dim2_variable_list + ['file'])]

# Reorder columns based on 'dim2_variable_list', placing 'file' first
df_dim2_normed_ordered = df_dim2_normed_filtered[['file'] + dim2_variable_list]

# Display the updated DataFrame
df_dim2_normed_ordered
# Out:
#       file    nounque     prnque    advcomp      ncogn  nqueinfcl  clinfadj  \
# 0  t000001  10.582011  10.582011   5.291005  21.164021   0.000000         0
# 1  t000002  21.917808  16.438356   5.479452   5.479452   0.000000         0
# 2  t000003   8.438819  25.316456  12.658228   0.000000   8.438819         0
# 3  t000004  30.075188  18.796992   3.759398   7.518797   0.000000         0
# 4  t000005   6.711409   6.711409  10.067114   6.711409   0.000000         0
# 5  t000006  26.239067   8.746356   2.915452  14.577259   0.000000         0
#
#    clqueeprp     prndem   clinfprp     adjque  clinfadjease   advhedg  \
# 0   0.000000  31.746032  42.328042  10.582011             0  0.000000
# 1   0.000000  30.136986  27.397260   0.000000             0  5.479452
# 2   0.000000  33.755274  42.194093   8.438819             0  0.000000
# 3   0.000000  30.075188  30.075188   0.000000             0  0.000000
# 4   0.000000  36.912752  40.268456   0.000000             0  0.000000
# 5   5.830904  23.323615  17.492711   0.000000             0  0.000000
#
#     artindef  vbfutpret     cjadv
# 0   0.000000          0  0.000000
# 1  19.178082          0  5.479452
# 2  12.658228          0  4.219409
# 3  15.037594          0  0.000000
# 4   3.355705          0  6.711409
# 5  20.408163          0  0.000000

# %% [markdown]
# ### Standardizing the normed counts

# %%
# Creating a new DataFrame with the 'file' column retained
df_dim2_standardised = df_dim2_normed_ordered[['file']].copy()

# %%
# Mapping Variable MS and SD for standardisation
var_dim_dict = dict(zip(df_var_dim['Variable Label'], zip(df_var_dim['Variable MS'], df_var_dim['Variable SD'])))

# %%
# Loop through columns except 'file'
for col in df_dim2_normed_ordered.columns[1:]:
    if col in var_dim_dict:
        mean_value, sd_value = var_dim_dict[col]
        df_dim2_standardised[col] = (df_dim2_normed_ordered[col] - mean_value) / sd_value

# Display the resulting DataFrame
df_dim2_standardised
# Out:
#       file   nounque    prnque   advcomp     ncogn  nqueinfcl  clinfadj  \
# 0  t000001  1.303584  0.067638 -0.793980  2.485073  -0.715686  -0.54717
# 1  t000002  4.426393  1.132428 -0.757388 -0.237942  -0.715686  -0.54717
# 2  t000003  0.713173  2.746628  0.636549 -1.189236   7.557665  -0.54717
# 3  t000004  6.673606  1.561271 -1.091379  0.116111  -0.715686  -0.54717
# 4  t000005  0.237303 -0.636107  0.133420 -0.024061  -0.715686  -0.54717
# 5  t000006  5.616823 -0.266117 -1.255252  1.341538  -0.715686  -0.54717
#
#    clqueeprp    prndem  clinfprp    adjque  clinfadjease   advhedg  artindef  \
# 0  -0.820312  2.915855  7.130481  0.326360     -0.370968 -0.676923 -1.788265
# 1  -0.820312  2.684004  3.926451 -1.802817     -0.370968  3.538040  0.657919
# 2  -0.820312  3.205371  7.101737 -0.104865     -0.370968 -0.676923 -0.173695
# 3  -0.820312  2.675099  4.501113 -1.802817     -0.370968 -0.676923  0.129795
# 4  -0.820312  3.660339  6.688510 -1.802817     -0.370968 -0.676923 -1.360242
# 5   3.735081  1.702250  1.801011 -1.802817     -0.370968 -0.676923  0.814817
#
#    vbfutpret     cjadv
# 0  -0.693487 -1.008621
# 1  -0.693487  1.353212
# 2  -0.693487  0.810090
# 3  -0.693487 -1.008621
# 4  -0.693487  1.884228
# 5  -0.693487 -1.008621

# %% [markdown]
# ### Computing the dimension scores

# %%
dim2_variable_list_pos = [
    'nounque',
    'prnque',
    'advcomp',
    'ncogn',
    'nqueinfcl',
    'clinfadj',
    'clqueeprp',
    'prndem',
    'clinfprp',
    'adjque',
    'clinfadjease',
    'advhedg',
    'artindef',
    'vbfutpret',
    'cjadv'
]

# %%
dim2_variable_list_neg = [
]

# %%
# Calculate the sum of positive pole variables
df_dim2_standardised['dim_scores'] = df_dim2_standardised[dim2_variable_list_pos].sum(axis=1)

# Subtract the sum of negative pole variables
df_dim2_standardised['dim_scores'] -= df_dim2_standardised[dim2_variable_list_neg].sum(axis=1)

# Display the updated DataFrame
df_dim2_standardised
# Out:
#       file   nounque    prnque   advcomp     ncogn  nqueinfcl  clinfadj  \
# 0  t000001  1.303584  0.067638 -0.793980  2.485073  -0.715686  -0.54717
# 1  t000002  4.426393  1.132428 -0.757388 -0.237942  -0.715686  -0.54717
# 2  t000003  0.713173  2.746628  0.636549 -1.189236   7.557665  -0.54717
# 3  t000004  6.673606  1.561271 -1.091379  0.116111  -0.715686  -0.54717
# 4  t000005  0.237303 -0.636107  0.133420 -0.024061  -0.715686  -0.54717
# 5  t000006  5.616823 -0.266117 -1.255252  1.341538  -0.715686  -0.54717
#
#    clqueeprp    prndem  clinfprp    adjque  clinfadjease   advhedg  artindef  \
# 0  -0.820312  2.915855  7.130481  0.326360     -0.370968 -0.676923 -1.788265
# 1  -0.820312  2.684004  3.926451 -1.802817     -0.370968  3.538040  0.657919
# 2  -0.820312  3.205371  7.101737 -0.104865     -0.370968 -0.676923 -0.173695
# 3  -0.820312  2.675099  4.501113 -1.802817     -0.370968 -0.676923  0.129795
# 4  -0.820312  3.660339  6.688510 -1.802817     -0.370968 -0.676923 -1.360242
# 5   3.735081  1.702250  1.801011 -1.802817     -0.370968 -0.676923  0.814817
#
#    vbfutpret     cjadv  dim_scores
# 0  -0.693487 -1.008621    6.813580
# 1  -0.693487  1.353212   11.772677
# 2  -0.693487  0.810090   18.194557
# 3  -0.693487 -1.008621    7.929633
# 4  -0.693487  1.884228    4.956027
# 5  -0.693487 -1.008621    7.674480

# %% [markdown]
# #### Export to a file

# %%
df_dim2_standardised.to_excel(f"{output_directory}/df_dim2_standardised.xlsx")

# %% [markdown]
# ### Computing the mean dimension scores for the new registers

# %%
mean_dim2_scores = df_dim2_standardised['dim_scores'].mean()
mean_dim2_scores
# Out:
# 9.55682556020905

# %% [markdown]
# ## Dimension 3

# %% [markdown]
# ### Filter and order `df_normed_labeled` according `dim3_variable_list`

# %% [markdown]
# The negative pole starts at `Type–token ratio [ttr]`.

# %%
dim3_variable_list = [
    'qsttag',
    'contrac',
    'discmrkr',
    'qsyn',
    'prn3sngsubj',
    'prn3plusubj',
    'cjcncl',
    'advpl',
    'mdter',
    'ttr'
]

# %%
# Ensure only columns from 'dim3_variable_list' remain
df_dim3_normed_filtered = df_normed_labeled[df_normed_labeled.columns.intersection(dim3_variable_list + ['file'])]

# Reorder columns based on 'dim3_variable_list', placing 'file' first
df_dim3_normed_ordered = df_dim3_normed_filtered[['file'] + dim3_variable_list]

# Display the updated DataFrame
df_dim3_normed_ordered
# Out:
#       file  qsttag  contrac  discmrkr  qsyn  prn3sngsubj  prn3plusubj  cjcncl  \
# 0  t000001       0        0         0     0     0.000000     0.000000       0
# 1  t000002       0        0         0     0     0.000000     5.479452       0
# 2  t000003       0        0         0     0     4.219409     0.000000       0
# 3  t000004       0        0         0     0     0.000000     0.000000       0
# 4  t000005       0        0         0     0     6.711409     0.000000       0
# 5  t000006       0        0         0     0     0.000000     2.915452       0
#
#       advpl  mdter       ttr
# 0  0.000000      0  2.444444
# 1  0.000000      0  1.210959
# 2  4.219409      0  1.983122
# 3  0.000000      0  1.729323
# 4  0.000000      0  1.526846
# 5  0.000000      0  1.230321

# %% [markdown]
# ### Standardizing the normed counts

# %%
# Creating a new DataFrame with the 'file' column retained
df_dim3_standardised = df_dim3_normed_ordered[['file']].copy()

# %%
# Mapping Variable MS and SD for standardisation
var_dim_dict = dict(zip(df_var_dim['Variable Label'], zip(df_var_dim['Variable MS'], df_var_dim['Variable SD'])))

# %%
# Loop through columns except 'file'
for col in df_dim3_normed_ordered.columns[1:]:
    if col in var_dim_dict:
        mean_value, sd_value = var_dim_dict[col]
        df_dim3_standardised[col] = (df_dim3_normed_ordered[col] - mean_value) / sd_value

# Display the resulting DataFrame
df_dim3_standardised
# Out:
#       file    qsttag   contrac  discmrkr      qsyn  prn3sngsubj  prn3plusubj  \
# 0  t000001 -0.235012 -0.309302 -0.906198 -0.484928    -0.609977    -0.509091
# 1  t000002 -0.235012 -0.309302 -0.906198 -0.484928    -0.609977     4.472229
# 2  t000003 -0.235012 -0.309302 -0.906198 -0.484928     0.346805    -0.509091
# 3  t000004 -0.235012 -0.309302 -0.906198 -0.484928    -0.609977    -0.509091
# 4  t000005 -0.235012 -0.309302 -0.906198 -0.484928     0.911884    -0.509091
# 5  t000006 -0.235012 -0.309302 -0.906198 -0.484928    -0.609977     2.141320
#
#    cjcncl     advpl     mdter        ttr
# 0    -0.8 -0.814371 -0.611111  27.349206
# 1    -0.8 -0.814371 -0.611111   9.727984
# 2    -0.8  0.027826 -0.611111  20.758891
# 3    -0.8 -0.814371 -0.611111  17.133190
# 4    -0.8 -0.814371 -0.611111  14.240652
# 5    -0.8 -0.814371 -0.611111  10.004581

# %% [markdown]
# ### Computing the dimension scores

# %%
dim3_variable_list_pos = [
    'qsttag',
    'contrac',
    'discmrkr',
    'qsyn',
    'prn3sngsubj',
    'prn3plusubj',
    'cjcncl',
    'advpl',
    'mdter'
]

# %%
dim3_variable_list_neg = [
    'ttr'
]

# %%
# Calculate the sum of positive pole variables
df_dim3_standardised['dim_scores'] = df_dim3_standardised[dim3_variable_list_pos].sum(axis=1)

# Subtract the sum of negative pole variables
df_dim3_standardised['dim_scores'] -= df_dim3_standardised[dim3_variable_list_neg].sum(axis=1)

# Display the updated DataFrame
df_dim3_standardised
# Out:
#       file    qsttag   contrac  discmrkr      qsyn  prn3sngsubj  prn3plusubj  \
# 0  t000001 -0.235012 -0.309302 -0.906198 -0.484928    -0.609977    -0.509091
# 1  t000002 -0.235012 -0.309302 -0.906198 -0.484928    -0.609977     4.472229
# 2  t000003 -0.235012 -0.309302 -0.906198 -0.484928     0.346805    -0.509091
# 3  t000004 -0.235012 -0.309302 -0.906198 -0.484928    -0.609977    -0.509091
# 4  t000005 -0.235012 -0.309302 -0.906198 -0.484928     0.911884    -0.509091
# 5  t000006 -0.235012 -0.309302 -0.906198 -0.484928    -0.609977     2.141320
#
#    cjcncl     advpl     mdter        ttr  dim_scores
# 0    -0.8 -0.814371 -0.611111  27.349206  -32.629197
# 1    -0.8 -0.814371 -0.611111   9.727984  -10.026655
# 2    -0.8  0.027826 -0.611111  20.758891  -24.239902
# 3    -0.8 -0.814371 -0.611111  17.133190  -22.413181
# 4    -0.8 -0.814371 -0.611111  14.240652  -17.998781
# 5    -0.8 -0.814371 -0.611111  10.004581  -12.634161

# %% [markdown]
# #### Export to a file

# %%
df_dim3_standardised.to_excel(f"{output_directory}/df_dim3_standardised.xlsx")

# %% [markdown]
# ### Computing the mean dimension scores for the new registers

# %%
mean_dim3_scores = df_dim3_standardised['dim_scores'].mean()
mean_dim3_scores
# Out:
# -19.99031266960335

# %% [markdown]
# ## Dimension 4

# %% [markdown]
# ### Filter and order `df_normed_labeled` according `dim4_variable_list`

# %% [markdown]
# The dimension has no negative pole.

# %%
dim4_variable_list = [
    'vbsubpres',
    'vbimp',
    'nconc',
    'subjdrop',
    'vbfacil',
    'cjcoorcls'
]

# %%
# Ensure only columns from 'dim4_variable_list' remain
df_dim4_normed_filtered = df_normed_labeled[df_normed_labeled.columns.intersection(dim4_variable_list + ['file'])]

# Reorder columns based on 'dim4_variable_list', placing 'file' first
df_dim4_normed_ordered = df_dim4_normed_filtered[['file'] + dim4_variable_list]

# Display the updated DataFrame
df_dim4_normed_ordered
# Out:
#       file  vbsubpres  vbimp      nconc  subjdrop    vbfacil  cjcoorcls
# 0  t000001   5.291005      0  10.582011         0  15.873016  21.164021
# 1  t000002   5.479452      0   8.219178         0   8.219178  10.958904
# 2  t000003   8.438819      0   4.219409         0   4.219409  16.877637
# 3  t000004   3.759398      0   0.000000         0  30.075188  45.112782
# 4  t000005   6.711409      0   3.355705         0  16.778523  50.335570
# 5  t000006   8.746356      0   2.915452         0   8.746356  14.577259

# %% [markdown]
# ### Standardizing the normed counts

# %%
# Creating a new DataFrame with the 'file' column retained
df_dim4_standardised = df_dim4_normed_ordered[['file']].copy()

# %%
# Mapping Variable MS and SD for standardisation
var_dim_dict = dict(zip(df_var_dim['Variable Label'], zip(df_var_dim['Variable MS'], df_var_dim['Variable SD'])))

# %%
# Loop through columns except 'file'
for col in df_dim4_normed_ordered.columns[1:]:
    if col in var_dim_dict:
        mean_value, sd_value = var_dim_dict[col]
        df_dim4_standardised[col] = (df_dim4_normed_ordered[col] - mean_value) / sd_value

# Display the resulting DataFrame
df_dim4_standardised
# Out:
#       file  vbsubpres     vbimp     nconc  subjdrop   vbfacil  cjcoorcls
# 0  t000001  -0.135325 -0.498567 -0.846366 -1.225836  4.047992   1.621527
# 1  t000002  -0.110299 -0.498567 -1.039251 -1.225836  1.479590  -0.068062
# 2  t000003   0.282712 -0.498567 -1.365763 -1.225836  0.137386   0.911860
# 3  t000004  -0.338725 -0.498567 -1.710204 -1.225836  8.813821   5.586553
# 4  t000005   0.053308 -0.498567 -1.436269 -1.225836  4.351854   6.451253
# 5  t000006   0.323553 -0.498567 -1.472208 -1.225836  1.656495   0.531003

# %% [markdown]
# ### Computing the dimension scores

# %%
dim4_variable_list_pos = [
    'vbsubpres',
    'vbimp',
    'nconc',
    'subjdrop',
    'vbfacil',
    'cjcoorcls'
]

# %%
dim4_variable_list_neg = [
]

# %%
# Calculate the sum of positive pole variables
df_dim4_standardised['dim_scores'] = df_dim4_standardised[dim4_variable_list_pos].sum(axis=1)

# Subtract the sum of negative pole variables
df_dim4_standardised['dim_scores'] -= df_dim4_standardised[dim4_variable_list_neg].sum(axis=1)

# Display the updated DataFrame
df_dim4_standardised
# Out:
#       file  vbsubpres     vbimp     nconc  subjdrop   vbfacil  cjcoorcls  \
# 0  t000001  -0.135325 -0.498567 -0.846366 -1.225836  4.047992   1.621527
# 1  t000002  -0.110299 -0.498567 -1.039251 -1.225836  1.479590  -0.068062
# 2  t000003   0.282712 -0.498567 -1.365763 -1.225836  0.137386   0.911860
# 3  t000004  -0.338725 -0.498567 -1.710204 -1.225836  8.813821   5.586553
# 4  t000005   0.053308 -0.498567 -1.436269 -1.225836  4.351854   6.451253
# 5  t000006   0.323553 -0.498567 -1.472208 -1.225836  1.656495   0.531003
#
#    dim_scores
# 0    2.963425
# 1   -1.462425
# 2   -1.758208
# 3   10.627042
# 4    7.695743
# 5   -0.685559

# %% [markdown]
# #### Export to a file

# %%
df_dim4_standardised.to_excel(f"{output_directory}/df_dim4_standardised.xlsx")

# %% [markdown]
# ### Computing the mean dimension scores for the new registers

# %%
mean_dim4_scores = df_dim4_standardised['dim_scores'].mean()
mean_dim4_scores
# Out:
# 2.8966697472174783

# %% [markdown]
# ## Dimension 5

# %% [markdown]
# ### Filter and order `df_normed_labeled` according `dim5_variable_list`

# %% [markdown]
# The negative pole starts at `Nouns: Place [nplac]`.

# %%
dim5_variable_list = [
    'vbsubfut',
    'cjou',
    'vbfutpres',
    'mddever',
    'mdpoder',
    'cjcond',
    'advlikl',
    'cjcoorphr',
    'nplac',
    'vbsubpast',
    'adjaffi',
    'vbimpf',
    'vbpast'
]

# %%
# Ensure only columns from 'dim5_variable_list' remain
df_dim5_normed_filtered = df_normed_labeled[df_normed_labeled.columns.intersection(dim5_variable_list + ['file'])]

# Reorder columns based on 'dim5_variable_list', placing 'file' first
df_dim5_normed_ordered = df_dim5_normed_filtered[['file'] + dim5_variable_list]

# Display the updated DataFrame
df_dim5_normed_ordered
# Out:
#       file  vbsubfut       cjou  vbfutpres  mddever    mdpoder  cjcond  \
# 0  t000001  0.000000   5.291005   0.000000        0   0.000000       0
# 1  t000002  8.219178   0.000000   2.739726        0  16.438356       0
# 2  t000003  0.000000  12.658228   0.000000        0   8.438819       0
# 3  t000004  0.000000   0.000000   0.000000        0   0.000000       0
# 4  t000005  0.000000   0.000000   0.000000        0   0.000000       0
# 5  t000006  2.915452   0.000000   0.000000        0   0.000000       0
#
#     advlikl  cjcoorphr     nplac  vbsubpast   adjaffi    vbimpf     vbpast
# 0  0.000000  31.746032  0.000000          0  0.000000  0.000000  42.328042
# 1  5.479452  16.438356  0.000000          0  2.739726  5.479452  27.397260
# 2  8.438819   0.000000  0.000000          0  0.000000  8.438819  46.413502
# 3  0.000000  45.112782  3.759398          0  0.000000  7.518797  26.315789
# 4  6.711409  10.067114  0.000000          0  3.355705  0.000000  36.912752
# 5  0.000000  17.492711  2.915452          0  0.000000  2.915452  20.408163

# %% [markdown]
# ### Standardizing the normed counts

# %%
# Creating a new DataFrame with the 'file' column retained
df_dim5_standardised = df_dim5_normed_ordered[['file']].copy()

# %%
# Mapping Variable MS and SD for standardisation
var_dim_dict = dict(zip(df_var_dim['Variable Label'], zip(df_var_dim['Variable MS'], df_var_dim['Variable SD'])))

# %%
# Loop through columns except 'file'
for col in df_dim5_normed_ordered.columns[1:]:
    if col in var_dim_dict:
        mean_value, sd_value = var_dim_dict[col]
        df_dim5_standardised[col] = (df_dim5_normed_ordered[col] - mean_value) / sd_value

# Display the resulting DataFrame
df_dim5_standardised
# Out:
#       file  vbsubfut      cjou  vbfutpres   mddever   mdpoder    cjcond  \
# 0  t000001 -0.683333  0.450475  -0.634304 -0.623711 -1.062284 -0.823232
# 1  t000002  2.056393 -0.803318  -0.190983 -0.623711  4.625729 -0.823232
# 2  t000003 -0.683333  2.196263  -0.634304 -0.623711  1.857723 -0.823232
# 3  t000004 -0.683333 -0.803318  -0.634304 -0.623711 -1.062284 -0.823232
# 4  t000005 -0.683333 -0.803318  -0.634304 -0.623711 -1.062284 -0.823232
# 5  t000006  0.288484 -0.803318  -0.634304 -0.623711 -1.062284 -0.823232
#
#     advlikl  cjcoorphr     nplac  vbsubpast   adjaffi    vbimpf    vbpast
# 0 -0.904192   4.747394 -1.168622  -0.610778 -0.581673 -0.703892  1.314552
# 1  2.376917   1.891484 -1.168622  -0.610778  0.509851 -0.240317  0.452498
# 2  4.148993  -1.175373 -1.168622  -0.610778 -0.581673  0.010052  1.550433
# 3 -0.904192   7.241191 -0.617390  -0.610778 -0.581673 -0.067784  0.390057
# 4  3.114616   0.702820 -1.168622  -0.610778  0.755261 -0.703892  1.001891
# 5 -0.904192   2.088192 -0.741136  -0.610778 -0.581673 -0.457238  0.048970

# %% [markdown]
# ### Computing the dimension scores

# %%
dim5_variable_list_pos = [
    'vbsubfut',
    'cjou',
    'vbfutpres',
    'mddever',
    'mdpoder',
    'cjcond',
    'advlikl',
    'cjcoorphr'
]

# %%
dim5_variable_list_neg = [
    'nplac',
    'vbsubpast',
    'adjaffi',
    'vbimpf',
    'vbpast'
]

# %%
# Calculate the sum of positive pole variables
df_dim5_standardised['dim_scores'] = df_dim5_standardised[dim5_variable_list_pos].sum(axis=1)

# Subtract the sum of negative pole variables
df_dim5_standardised['dim_scores'] -= df_dim5_standardised[dim5_variable_list_neg].sum(axis=1)

# Display the updated DataFrame
df_dim5_standardised
# Out:
#       file  vbsubfut      cjou  vbfutpres   mddever   mdpoder    cjcond  \
# 0  t000001 -0.683333  0.450475  -0.634304 -0.623711 -1.062284 -0.823232
# 1  t000002  2.056393 -0.803318  -0.190983 -0.623711  4.625729 -0.823232
# 2  t000003 -0.683333  2.196263  -0.634304 -0.623711  1.857723 -0.823232
# 3  t000004 -0.683333 -0.803318  -0.634304 -0.623711 -1.062284 -0.823232
# 4  t000005 -0.683333 -0.803318  -0.634304 -0.623711 -1.062284 -0.823232
# 5  t000006  0.288484 -0.803318  -0.634304 -0.623711 -1.062284 -0.823232
#
#     advlikl  cjcoorphr     nplac  vbsubpast   adjaffi    vbimpf    vbpast  \
# 0 -0.904192   4.747394 -1.168622  -0.610778 -0.581673 -0.703892  1.314552
# 1  2.376917   1.891484 -1.168622  -0.610778  0.509851 -0.240317  0.452498
# 2  4.148993  -1.175373 -1.168622  -0.610778 -0.581673  0.010052  1.550433
# 3 -0.904192   7.241191 -0.617390  -0.610778 -0.581673 -0.067784  0.390057
# 4  3.114616   0.702820 -1.168622  -0.610778  0.755261 -0.703892  1.001891
# 5 -0.904192   2.088192 -0.741136  -0.610778 -0.581673 -0.457238  0.048970
#
#    dim_scores
# 0    2.217226
# 1    9.566648
# 2    5.063612
# 3    3.194385
# 4   -0.086606
# 5   -0.132509

# %% [markdown]
# #### Export to a file

# %%
df_dim5_standardised.to_excel(f"{output_directory}/df_dim5_standardised.xlsx")

# %% [markdown]
# ### Computing the mean dimension scores for the new registers

# %%
mean_dim5_scores = df_dim5_standardised['dim_scores'].mean()
mean_dim5_scores
# Out:
# 3.3037925194906452

# %% [markdown]
# ## Dimension 6

# %% [markdown]
# ### Filter and order `df_normed_labeled` according `dim6_variable_list`

# %% [markdown]
# The negative pole starts at `Adjectives: Evaluative [adjeval]`, this is a variable that is excluded from the analysis, though.

# %%
dim6_variable_list = [
    'objprnrare',
    'vb2',
    'prnposs',
    'cjfinal',
    'prn3obl',
    'vbpubl',
    'mdhaver'
]

# %%
# Ensure only columns from 'dim6_variable_list' remain
df_dim6_normed_filtered = df_normed_labeled[df_normed_labeled.columns.intersection(dim6_variable_list + ['file'])]

# Reorder columns based on 'dim6_variable_list', placing 'file' first
df_dim6_normed_ordered = df_dim6_normed_filtered[['file'] + dim6_variable_list]

# Display the updated DataFrame
df_dim6_normed_ordered
# Out:
#       file  objprnrare  vb2    prnposs  cjfinal    prn3obl     vbpubl  mdhaver
# 0  t000001           0    0  10.582011        0   0.000000  15.873016        0
# 1  t000002           0    0   2.739726        0   2.739726   8.219178        0
# 2  t000003           0    0   0.000000        0  21.097046  12.658228        0
# 3  t000004           0    0  11.278195        0   0.000000  11.278195        0
# 4  t000005           0    0   0.000000        0  20.134228   6.711409        0
# 5  t000006           0    0   5.830904        0   8.746356  14.577259        0

# %% [markdown]
# ### Standardizing the normed counts

# %%
# Creating a new DataFrame with the 'file' column retained
df_dim6_standardised = df_dim6_normed_ordered[['file']].copy()

# %%
# Mapping Variable MS and SD for standardisation
var_dim_dict = dict(zip(df_var_dim['Variable Label'], zip(df_var_dim['Variable MS'], df_var_dim['Variable SD'])))

# %%
# Loop through columns except 'file'
for col in df_dim6_normed_ordered.columns[1:]:
    if col in var_dim_dict:
        mean_value, sd_value = var_dim_dict[col]
        df_dim6_standardised[col] = (df_dim6_normed_ordered[col] - mean_value) / sd_value

# Display the resulting DataFrame
df_dim6_standardised
# Out:
#       file  objprnrare       vb2   prnposs  cjfinal   prn3obl    vbpubl  \
# 0  t000001    -0.53012 -0.347826 -0.008685   -0.125 -1.372439  0.946287
# 1  t000002    -0.53012 -0.347826 -0.881990   -0.125 -0.862248 -0.238517
# 2  t000003    -0.53012 -0.347826 -1.187082   -0.125  2.556247  0.448642
# 3  t000004    -0.53012 -0.347826  0.068841   -0.125 -1.372439  0.235015
# 4  t000005    -0.53012 -0.347826 -1.187082   -0.125  2.376951 -0.471918
# 5  t000006    -0.53012 -0.347826 -0.537761   -0.125  0.256305  0.745706
#
#     mdhaver
# 0 -0.217391
# 1 -0.217391
# 2 -0.217391
# 3 -0.217391
# 4 -0.217391
# 5 -0.217391

# %% [markdown]
# ### Computing the dimension scores

# %%
dim6_variable_list_pos = [
    'objprnrare',
    'vb2',
    'prnposs',
    'cjfinal',
    'prn3obl',
    'vbpubl',
    'mdhaver'
]

# %%
dim6_variable_list_neg = [
]

# %%
# Calculate the sum of positive pole variables
df_dim6_standardised['dim_scores'] = df_dim6_standardised[dim6_variable_list_pos].sum(axis=1)

# Subtract the sum of negative pole variables
df_dim6_standardised['dim_scores'] -= df_dim6_standardised[dim6_variable_list_neg].sum(axis=1)

# Display the updated DataFrame
df_dim6_standardised
# Out:
#       file  objprnrare       vb2   prnposs  cjfinal   prn3obl    vbpubl  \
# 0  t000001    -0.53012 -0.347826 -0.008685   -0.125 -1.372439  0.946287
# 1  t000002    -0.53012 -0.347826 -0.881990   -0.125 -0.862248 -0.238517
# 2  t000003    -0.53012 -0.347826 -1.187082   -0.125  2.556247  0.448642
# 3  t000004    -0.53012 -0.347826  0.068841   -0.125 -1.372439  0.235015
# 4  t000005    -0.53012 -0.347826 -1.187082   -0.125  2.376951 -0.471918
# 5  t000006    -0.53012 -0.347826 -0.537761   -0.125  0.256305  0.745706
#
#     mdhaver  dim_scores
# 0 -0.217391   -1.655175
# 1 -0.217391   -3.203094
# 2 -0.217391    0.597469
# 3 -0.217391   -2.288921
# 4 -0.217391   -0.502387
# 5 -0.217391   -0.756089

# %% [markdown]
# #### Export to a file

# %%
df_dim6_standardised.to_excel(f"{output_directory}/df_dim6_standardised.xlsx")

# %% [markdown]
# ### Computing the mean dimension scores for the new registers

# %%
mean_dim6_scores = df_dim6_standardised['dim_scores'].mean()
mean_dim6_scores
# Out:
# -1.3013661848024505

# %% [markdown]
# ## Summary

# %%
# Define data
dimensions = [f'Dimension {i}' for i in range(1, 7)]
mean_scores = [mean_dim1_scores, mean_dim2_scores, mean_dim3_scores, mean_dim4_scores, mean_dim5_scores, mean_dim6_scores]

# Create the DataFrame
df_mean_dim_scores = pd.DataFrame({'Dimension': dimensions, 'Mean Dimension Score': mean_scores})

# Display the DataFrame
df_mean_dim_scores
# Out:
#      Dimension  Mean Dimension Score
# 0  Dimension 1            -70.227612
# 1  Dimension 2              9.556826
# 2  Dimension 3            -19.990313
# 3  Dimension 4              2.896670
# 4  Dimension 5              3.303793
# 5  Dimension 6             -1.301366

# %% [markdown]
# ### Export to a file

# %%
df_mean_dim_scores.to_excel(f"{output_directory}/df_mean_dim_scores.xlsx")
